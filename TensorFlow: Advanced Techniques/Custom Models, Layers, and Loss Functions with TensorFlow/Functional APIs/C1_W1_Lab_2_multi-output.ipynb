# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Get the data from UCI dataset
URL = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URL)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 249.3006 - y1_output_loss: 119.9729 - y2_output_loss: 127.9110 - y1_output_root_mean_squared_error: 10.9909 - y2_output_root_mean_squared_error: 11.3358 - val_loss: 97.0840 - val_y1_output_loss: 24.6826 - val_y2_output_loss: 72.6980 - val_y1_output_root_mean_squared_error: 4.9564 - val_y2_output_root_mean_squared_error: 8.5158
# Epoch 2/500
# 614/614 [==============================] - 0s 139us/sample - loss: 28.5716 - y1_output_loss: 11.4344 - y2_output_loss: 17.2692 - y1_output_root_mean_squared_error: 3.3477 - y2_output_root_mean_squared_error: 4.1670 - val_loss: 37.0621 - val_y1_output_loss: 15.9347 - val_y2_output_loss: 20.5473 - val_y1_output_root_mean_squared_error: 4.0200 - val_y2_output_root_mean_squared_error: 4.5718
# Epoch 3/500
# 614/614 [==============================] - 0s 140us/sample - loss: 24.1617 - y1_output_loss: 9.5288 - y2_output_loss: 14.5165 - y1_output_root_mean_squared_error: 3.0967 - y2_output_root_mean_squared_error: 3.8173 - val_loss: 22.5656 - val_y1_output_loss: 10.3486 - val_y2_output_loss: 11.6832 - val_y1_output_root_mean_squared_error: 3.2387 - val_y2_output_root_mean_squared_error: 3.4751
# Epoch 4/500
# 614/614 [==============================] - 0s 134us/sample - loss: 22.9690 - y1_output_loss: 8.7174 - y2_output_loss: 14.1698 - y1_output_root_mean_squared_error: 2.9576 - y2_output_root_mean_squared_error: 3.7712 - val_loss: 24.1221 - val_y1_output_loss: 10.0398 - val_y2_output_loss: 13.7660 - val_y1_output_root_mean_squared_error: 3.1646 - val_y2_output_root_mean_squared_error: 3.7560
# Epoch 5/500
# 614/614 [==============================] - 0s 133us/sample - loss: 24.7032 - y1_output_loss: 9.0413 - y2_output_loss: 15.5743 - y1_output_root_mean_squared_error: 3.0018 - y2_output_root_mean_squared_error: 3.9614 - val_loss: 27.3664 - val_y1_output_loss: 11.1157 - val_y2_output_loss: 15.5268 - val_y1_output_root_mean_squared_error: 3.3626 - val_y2_output_root_mean_squared_error: 4.0074
# Epoch 6/500
# 614/614 [==============================] - 0s 133us/sample - loss: 23.0824 - y1_output_loss: 8.4221 - y2_output_loss: 14.8613 - y1_output_root_mean_squared_error: 2.8956 - y2_output_root_mean_squared_error: 3.8338 - val_loss: 75.6340 - val_y1_output_loss: 15.1856 - val_y2_output_loss: 58.9275 - val_y1_output_root_mean_squared_error: 3.9622 - val_y2_output_root_mean_squared_error: 7.7418
# Epoch 7/500
# 614/614 [==============================] - 0s 132us/sample - loss: 26.1079 - y1_output_loss: 8.7849 - y2_output_loss: 17.2119 - y1_output_root_mean_squared_error: 2.9719 - y2_output_root_mean_squared_error: 4.1564 - val_loss: 25.2277 - val_y1_output_loss: 11.5788 - val_y2_output_loss: 13.4475 - val_y1_output_root_mean_squared_error: 3.3763 - val_y2_output_root_mean_squared_error: 3.7186
# Epoch 8/500
# 614/614 [==============================] - 0s 131us/sample - loss: 24.3822 - y1_output_loss: 8.6862 - y2_output_loss: 15.6987 - y1_output_root_mean_squared_error: 2.9400 - y2_output_root_mean_squared_error: 3.9672 - val_loss: 27.8109 - val_y1_output_loss: 12.0264 - val_y2_output_loss: 15.6587 - val_y1_output_root_mean_squared_error: 3.4381 - val_y2_output_root_mean_squared_error: 3.9988
# Epoch 9/500
# 614/614 [==============================] - 0s 132us/sample - loss: 23.6655 - y1_output_loss: 8.4579 - y2_output_loss: 14.9944 - y1_output_root_mean_squared_error: 2.9207 - y2_output_root_mean_squared_error: 3.8904 - val_loss: 21.1450 - val_y1_output_loss: 9.4197 - val_y2_output_loss: 11.2433 - val_y1_output_root_mean_squared_error: 3.0813 - val_y2_output_root_mean_squared_error: 3.4133
# Epoch 10/500
# 614/614 [==============================] - 0s 132us/sample - loss: 20.8423 - y1_output_loss: 8.0264 - y2_output_loss: 13.3002 - y1_output_root_mean_squared_error: 2.8234 - y2_output_root_mean_squared_error: 3.5876 - val_loss: 23.3308 - val_y1_output_loss: 9.8156 - val_y2_output_loss: 13.0212 - val_y1_output_root_mean_squared_error: 3.1398 - val_y2_output_root_mean_squared_error: 3.6705
# Epoch 11/500
# 614/614 [==============================] - 0s 132us/sample - loss: 25.5360 - y1_output_loss: 8.4469 - y2_output_loss: 16.8902 - y1_output_root_mean_squared_error: 2.9176 - y2_output_root_mean_squared_error: 4.1260 - val_loss: 20.6154 - val_y1_output_loss: 9.2930 - val_y2_output_loss: 10.8691 - val_y1_output_root_mean_squared_error: 3.0540 - val_y2_output_root_mean_squared_error: 3.3598
# Epoch 12/500
# 614/614 [==============================] - 0s 132us/sample - loss: 19.0639 - y1_output_loss: 7.2678 - y2_output_loss: 11.8804 - y1_output_root_mean_squared_error: 2.6921 - y2_output_root_mean_squared_error: 3.4375 - val_loss: 55.4259 - val_y1_output_loss: 14.2544 - val_y2_output_loss: 40.3074 - val_y1_output_root_mean_squared_error: 3.8136 - val_y2_output_root_mean_squared_error: 6.3940
# Epoch 13/500
# 614/614 [==============================] - 0s 131us/sample - loss: 17.9387 - y1_output_loss: 6.8213 - y2_output_loss: 10.9668 - y1_output_root_mean_squared_error: 2.6222 - y2_output_root_mean_squared_error: 3.3261 - val_loss: 19.7452 - val_y1_output_loss: 8.7078 - val_y2_output_loss: 10.5135 - val_y1_output_root_mean_squared_error: 2.9755 - val_y2_output_root_mean_squared_error: 3.3003
# Epoch 14/500
# 614/614 [==============================] - 0s 131us/sample - loss: 17.5276 - y1_output_loss: 6.4925 - y2_output_loss: 10.8960 - y1_output_root_mean_squared_error: 2.5572 - y2_output_root_mean_squared_error: 3.3148 - val_loss: 21.3967 - val_y1_output_loss: 9.8799 - val_y2_output_loss: 11.0710 - val_y1_output_root_mean_squared_error: 3.1557 - val_y2_output_root_mean_squared_error: 3.3821
# Epoch 15/500
# 614/614 [==============================] - 0s 127us/sample - loss: 18.3022 - y1_output_loss: 6.8540 - y2_output_loss: 11.2879 - y1_output_root_mean_squared_error: 2.6288 - y2_output_root_mean_squared_error: 3.3751 - val_loss: 18.9111 - val_y1_output_loss: 8.6416 - val_y2_output_loss: 9.9206 - val_y1_output_root_mean_squared_error: 2.9404 - val_y2_output_root_mean_squared_error: 3.2039
# Epoch 16/500
# 614/614 [==============================] - 0s 129us/sample - loss: 21.4919 - y1_output_loss: 7.5649 - y2_output_loss: 13.7860 - y1_output_root_mean_squared_error: 2.7599 - y2_output_root_mean_squared_error: 3.7249 - val_loss: 19.4238 - val_y1_output_loss: 8.1719 - val_y2_output_loss: 10.9613 - val_y1_output_root_mean_squared_error: 2.8528 - val_y2_output_root_mean_squared_error: 3.3594
# Epoch 17/500
# 614/614 [==============================] - 0s 132us/sample - loss: 15.3334 - y1_output_loss: 6.1147 - y2_output_loss: 9.4037 - y1_output_root_mean_squared_error: 2.4656 - y2_output_root_mean_squared_error: 3.0421 - val_loss: 119.6382 - val_y1_output_loss: 22.4808 - val_y2_output_loss: 96.6217 - val_y1_output_root_mean_squared_error: 4.7909 - val_y2_output_root_mean_squared_error: 9.8329
# Epoch 18/500
# 614/614 [==============================] - 0s 138us/sample - loss: 20.3617 - y1_output_loss: 6.5842 - y2_output_loss: 13.7421 - y1_output_root_mean_squared_error: 2.5727 - y2_output_root_mean_squared_error: 3.7072 - val_loss: 34.4937 - val_y1_output_loss: 9.6752 - val_y2_output_loss: 24.2075 - val_y1_output_root_mean_squared_error: 3.1589 - val_y2_output_root_mean_squared_error: 4.9513
# Epoch 19/500
# 614/614 [==============================] - 0s 133us/sample - loss: 15.4087 - y1_output_loss: 5.6840 - y2_output_loss: 9.6417 - y1_output_root_mean_squared_error: 2.3908 - y2_output_root_mean_squared_error: 3.1133 - val_loss: 18.0556 - val_y1_output_loss: 7.7155 - val_y2_output_loss: 9.9048 - val_y1_output_root_mean_squared_error: 2.7990 - val_y2_output_root_mean_squared_error: 3.1970
# Epoch 20/500
# 614/614 [==============================] - 0s 131us/sample - loss: 15.9678 - y1_output_loss: 5.9192 - y2_output_loss: 9.9163 - y1_output_root_mean_squared_error: 2.4437 - y2_output_root_mean_squared_error: 3.1617 - val_loss: 16.4720 - val_y1_output_loss: 7.0325 - val_y2_output_loss: 9.0264 - val_y1_output_root_mean_squared_error: 2.6683 - val_y2_output_root_mean_squared_error: 3.0582
# Epoch 21/500
# 614/614 [==============================] - 0s 136us/sample - loss: 15.4772 - y1_output_loss: 5.7626 - y2_output_loss: 9.7643 - y1_output_root_mean_squared_error: 2.3908 - y2_output_root_mean_squared_error: 3.1243 - val_loss: 48.1935 - val_y1_output_loss: 16.2478 - val_y2_output_loss: 31.9962 - val_y1_output_root_mean_squared_error: 4.0513 - val_y2_output_root_mean_squared_error: 5.6374
# Epoch 22/500
# 614/614 [==============================] - 0s 133us/sample - loss: 14.6883 - y1_output_loss: 5.3964 - y2_output_loss: 9.1971 - y1_output_root_mean_squared_error: 2.3311 - y2_output_root_mean_squared_error: 3.0421 - val_loss: 16.9818 - val_y1_output_loss: 7.3440 - val_y2_output_loss: 9.2874 - val_y1_output_root_mean_squared_error: 2.7155 - val_y2_output_root_mean_squared_error: 3.0996
# Epoch 23/500
# 614/614 [==============================] - 0s 135us/sample - loss: 13.6910 - y1_output_loss: 5.0152 - y2_output_loss: 8.7354 - y1_output_root_mean_squared_error: 2.2352 - y2_output_root_mean_squared_error: 2.9487 - val_loss: 17.7814 - val_y1_output_loss: 7.4982 - val_y2_output_loss: 9.8213 - val_y1_output_root_mean_squared_error: 2.7613 - val_y2_output_root_mean_squared_error: 3.1869
# Epoch 24/500
# 614/614 [==============================] - 0s 135us/sample - loss: 14.9818 - y1_output_loss: 5.3631 - y2_output_loss: 9.8736 - y1_output_root_mean_squared_error: 2.2810 - y2_output_root_mean_squared_error: 3.1271 - val_loss: 52.0331 - val_y1_output_loss: 16.4462 - val_y2_output_loss: 35.3174 - val_y1_output_root_mean_squared_error: 4.0341 - val_y2_output_root_mean_squared_error: 5.9799
# Epoch 25/500
# 614/614 [==============================] - 0s 134us/sample - loss: 13.6943 - y1_output_loss: 4.8765 - y2_output_loss: 8.7272 - y1_output_root_mean_squared_error: 2.2183 - y2_output_root_mean_squared_error: 2.9620 - val_loss: 14.6264 - val_y1_output_loss: 6.0278 - val_y2_output_loss: 8.2017 - val_y1_output_root_mean_squared_error: 2.4730 - val_y2_output_root_mean_squared_error: 2.9173
# Epoch 26/500
# 614/614 [==============================] - 0s 132us/sample - loss: 14.2347 - y1_output_loss: 5.0869 - y2_output_loss: 9.2039 - y1_output_root_mean_squared_error: 2.2608 - y2_output_root_mean_squared_error: 3.0205 - val_loss: 40.9662 - val_y1_output_loss: 9.7425 - val_y2_output_loss: 31.1219 - val_y1_output_root_mean_squared_error: 3.1547 - val_y2_output_root_mean_squared_error: 5.5690
# Epoch 27/500
# 614/614 [==============================] - 0s 134us/sample - loss: 14.1752 - y1_output_loss: 4.5748 - y2_output_loss: 9.6180 - y1_output_root_mean_squared_error: 2.1448 - y2_output_root_mean_squared_error: 3.0944 - val_loss: 14.7121 - val_y1_output_loss: 5.7258 - val_y2_output_loss: 8.6835 - val_y1_output_root_mean_squared_error: 2.4010 - val_y2_output_root_mean_squared_error: 2.9912
# Epoch 28/500
# 614/614 [==============================] - 0s 129us/sample - loss: 14.8782 - y1_output_loss: 5.0456 - y2_output_loss: 9.7336 - y1_output_root_mean_squared_error: 2.2520 - y2_output_root_mean_squared_error: 3.1315 - val_loss: 13.0846 - val_y1_output_loss: 5.3809 - val_y2_output_loss: 7.2844 - val_y1_output_root_mean_squared_error: 2.3519 - val_y2_output_root_mean_squared_error: 2.7483
# Epoch 29/500
# 614/614 [==============================] - 0s 129us/sample - loss: 12.2272 - y1_output_loss: 4.5786 - y2_output_loss: 7.5731 - y1_output_root_mean_squared_error: 2.1440 - y2_output_root_mean_squared_error: 2.7623 - val_loss: 12.5995 - val_y1_output_loss: 5.2314 - val_y2_output_loss: 7.0262 - val_y1_output_root_mean_squared_error: 2.3151 - val_y2_output_root_mean_squared_error: 2.6907
# Epoch 30/500
# 614/614 [==============================] - 0s 127us/sample - loss: 10.4734 - y1_output_loss: 3.8663 - y2_output_loss: 6.5592 - y1_output_root_mean_squared_error: 1.9713 - y2_output_root_mean_squared_error: 2.5666 - val_loss: 18.5659 - val_y1_output_loss: 6.8172 - val_y2_output_loss: 11.3394 - val_y1_output_root_mean_squared_error: 2.6215 - val_y2_output_root_mean_squared_error: 3.4196
# Epoch 31/500
# 614/614 [==============================] - 0s 128us/sample - loss: 10.4900 - y1_output_loss: 4.0095 - y2_output_loss: 6.7057 - y1_output_root_mean_squared_error: 1.9626 - y2_output_root_mean_squared_error: 2.5765 - val_loss: 43.9247 - val_y1_output_loss: 17.1576 - val_y2_output_loss: 26.2729 - val_y1_output_root_mean_squared_error: 4.1406 - val_y2_output_root_mean_squared_error: 5.1749
# Epoch 32/500
# 614/614 [==============================] - 0s 128us/sample - loss: 10.2073 - y1_output_loss: 3.7763 - y2_output_loss: 6.3397 - y1_output_root_mean_squared_error: 1.9519 - y2_output_root_mean_squared_error: 2.5293 - val_loss: 11.1716 - val_y1_output_loss: 4.5332 - val_y2_output_loss: 6.3433 - val_y1_output_root_mean_squared_error: 2.1520 - val_y2_output_root_mean_squared_error: 2.5574
# Epoch 33/500
# 614/614 [==============================] - 0s 127us/sample - loss: 12.4746 - y1_output_loss: 4.1781 - y2_output_loss: 8.2623 - y1_output_root_mean_squared_error: 2.0513 - y2_output_root_mean_squared_error: 2.8752 - val_loss: 15.5926 - val_y1_output_loss: 6.1578 - val_y2_output_loss: 9.0521 - val_y1_output_root_mean_squared_error: 2.5011 - val_y2_output_root_mean_squared_error: 3.0557
# Epoch 34/500
# 614/614 [==============================] - 0s 129us/sample - loss: 9.1955 - y1_output_loss: 3.4956 - y2_output_loss: 5.7836 - y1_output_root_mean_squared_error: 1.8582 - y2_output_root_mean_squared_error: 2.3964 - val_loss: 28.5959 - val_y1_output_loss: 12.4194 - val_y2_output_loss: 15.2843 - val_y1_output_root_mean_squared_error: 3.5710 - val_y2_output_root_mean_squared_error: 3.9805
# Epoch 35/500
# 614/614 [==============================] - 0s 128us/sample - loss: 12.4197 - y1_output_loss: 4.2587 - y2_output_loss: 8.0910 - y1_output_root_mean_squared_error: 2.0651 - y2_output_root_mean_squared_error: 2.8557 - val_loss: 11.0386 - val_y1_output_loss: 4.4484 - val_y2_output_loss: 6.3064 - val_y1_output_root_mean_squared_error: 2.1286 - val_y2_output_root_mean_squared_error: 2.5510
# Epoch 36/500
# 614/614 [==============================] - 0s 129us/sample - loss: 9.2044 - y1_output_loss: 3.3054 - y2_output_loss: 5.8865 - y1_output_root_mean_squared_error: 1.8238 - y2_output_root_mean_squared_error: 2.4245 - val_loss: 26.6315 - val_y1_output_loss: 6.1252 - val_y2_output_loss: 20.5699 - val_y1_output_root_mean_squared_error: 2.4993 - val_y2_output_root_mean_squared_error: 4.5150
# Epoch 37/500
# 614/614 [==============================] - 0s 127us/sample - loss: 9.1158 - y1_output_loss: 3.2930 - y2_output_loss: 5.8406 - y1_output_root_mean_squared_error: 1.8091 - y2_output_root_mean_squared_error: 2.4173 - val_loss: 14.5029 - val_y1_output_loss: 5.6760 - val_y2_output_loss: 8.7070 - val_y1_output_root_mean_squared_error: 2.4076 - val_y2_output_root_mean_squared_error: 2.9506
# Epoch 38/500
# 614/614 [==============================] - 0s 127us/sample - loss: 8.4257 - y1_output_loss: 3.1067 - y2_output_loss: 5.2645 - y1_output_root_mean_squared_error: 1.7691 - y2_output_root_mean_squared_error: 2.3013 - val_loss: 14.2522 - val_y1_output_loss: 5.5582 - val_y2_output_loss: 8.3453 - val_y1_output_root_mean_squared_error: 2.3650 - val_y2_output_root_mean_squared_error: 2.9426
# Epoch 39/500
# 614/614 [==============================] - 0s 127us/sample - loss: 7.2525 - y1_output_loss: 2.6798 - y2_output_loss: 4.5225 - y1_output_root_mean_squared_error: 1.6411 - y2_output_root_mean_squared_error: 2.1353 - val_loss: 11.1329 - val_y1_output_loss: 4.2333 - val_y2_output_loss: 6.6067 - val_y1_output_root_mean_squared_error: 2.0753 - val_y2_output_root_mean_squared_error: 2.6127
# Epoch 40/500
# 614/614 [==============================] - 0s 128us/sample - loss: 9.0844 - y1_output_loss: 2.9029 - y2_output_loss: 6.1023 - y1_output_root_mean_squared_error: 1.7108 - y2_output_root_mean_squared_error: 2.4814 - val_loss: 9.8429 - val_y1_output_loss: 3.5385 - val_y2_output_loss: 6.0499 - val_y1_output_root_mean_squared_error: 1.9013 - val_y2_output_root_mean_squared_error: 2.4956
# Epoch 41/500
# 614/614 [==============================] - 0s 127us/sample - loss: 8.1939 - y1_output_loss: 2.8778 - y2_output_loss: 5.3796 - y1_output_root_mean_squared_error: 1.6835 - y2_output_root_mean_squared_error: 2.3151 - val_loss: 10.4569 - val_y1_output_loss: 4.1685 - val_y2_output_loss: 6.0504 - val_y1_output_root_mean_squared_error: 2.0500 - val_y2_output_root_mean_squared_error: 2.5008
# Epoch 42/500
# 614/614 [==============================] - 0s 128us/sample - loss: 8.4618 - y1_output_loss: 2.8755 - y2_output_loss: 5.5615 - y1_output_root_mean_squared_error: 1.6907 - y2_output_root_mean_squared_error: 2.3671 - val_loss: 10.9924 - val_y1_output_loss: 4.2061 - val_y2_output_loss: 6.5047 - val_y1_output_root_mean_squared_error: 2.0683 - val_y2_output_root_mean_squared_error: 2.5913
# Epoch 43/500
# 614/614 [==============================] - 0s 127us/sample - loss: 7.7212 - y1_output_loss: 2.8304 - y2_output_loss: 4.9620 - y1_output_root_mean_squared_error: 1.6749 - y2_output_root_mean_squared_error: 2.2172 - val_loss: 19.9649 - val_y1_output_loss: 7.3160 - val_y2_output_loss: 12.0648 - val_y1_output_root_mean_squared_error: 2.7338 - val_y2_output_root_mean_squared_error: 3.5343
# Epoch 44/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.8440 - y1_output_loss: 2.6362 - y2_output_loss: 5.2150 - y1_output_root_mean_squared_error: 1.6281 - y2_output_root_mean_squared_error: 2.2789 - val_loss: 10.8500 - val_y1_output_loss: 3.6287 - val_y2_output_loss: 7.0221 - val_y1_output_root_mean_squared_error: 1.9289 - val_y2_output_root_mean_squared_error: 2.6701
# Epoch 45/500
# 614/614 [==============================] - 0s 127us/sample - loss: 7.8355 - y1_output_loss: 2.5367 - y2_output_loss: 5.2739 - y1_output_root_mean_squared_error: 1.5876 - y2_output_root_mean_squared_error: 2.3055 - val_loss: 9.1953 - val_y1_output_loss: 3.3866 - val_y2_output_loss: 5.6669 - val_y1_output_root_mean_squared_error: 1.8590 - val_y2_output_root_mean_squared_error: 2.3957
# Epoch 46/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.7062 - y1_output_loss: 2.5266 - y2_output_loss: 5.1678 - y1_output_root_mean_squared_error: 1.5966 - y2_output_root_mean_squared_error: 2.2709 - val_loss: 8.6445 - val_y1_output_loss: 2.9905 - val_y2_output_loss: 5.4364 - val_y1_output_root_mean_squared_error: 1.7444 - val_y2_output_root_mean_squared_error: 2.3668
# Epoch 47/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.2627 - y1_output_loss: 2.3228 - y2_output_loss: 4.9877 - y1_output_root_mean_squared_error: 1.5184 - y2_output_root_mean_squared_error: 2.2265 - val_loss: 24.0051 - val_y1_output_loss: 5.9761 - val_y2_output_loss: 18.4932 - val_y1_output_root_mean_squared_error: 2.4529 - val_y2_output_root_mean_squared_error: 4.2413
# Epoch 48/500
# 614/614 [==============================] - 0s 127us/sample - loss: 8.4258 - y1_output_loss: 2.6604 - y2_output_loss: 5.7720 - y1_output_root_mean_squared_error: 1.6278 - y2_output_root_mean_squared_error: 2.4033 - val_loss: 15.8692 - val_y1_output_loss: 5.3433 - val_y2_output_loss: 10.6725 - val_y1_output_root_mean_squared_error: 2.3212 - val_y2_output_root_mean_squared_error: 3.2375
# Epoch 49/500
# 614/614 [==============================] - 0s 127us/sample - loss: 7.3302 - y1_output_loss: 2.4074 - y2_output_loss: 4.9693 - y1_output_root_mean_squared_error: 1.5529 - y2_output_root_mean_squared_error: 2.2178 - val_loss: 9.1100 - val_y1_output_loss: 2.5002 - val_y2_output_loss: 6.6642 - val_y1_output_root_mean_squared_error: 1.5971 - val_y2_output_root_mean_squared_error: 2.5611
# Epoch 50/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.2056 - y1_output_loss: 2.2041 - y2_output_loss: 4.0030 - y1_output_root_mean_squared_error: 1.4908 - y2_output_root_mean_squared_error: 1.9957 - val_loss: 9.2412 - val_y1_output_loss: 2.6541 - val_y2_output_loss: 6.6011 - val_y1_output_root_mean_squared_error: 1.6482 - val_y2_output_root_mean_squared_error: 2.5543
# Epoch 51/500
# 614/614 [==============================] - 0s 127us/sample - loss: 7.9331 - y1_output_loss: 2.1788 - y2_output_loss: 5.6952 - y1_output_root_mean_squared_error: 1.4780 - y2_output_root_mean_squared_error: 2.3977 - val_loss: 6.8314 - val_y1_output_loss: 2.3243 - val_y2_output_loss: 4.4115 - val_y1_output_root_mean_squared_error: 1.5403 - val_y2_output_root_mean_squared_error: 2.1116
# Epoch 52/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.5340 - y1_output_loss: 2.1536 - y2_output_loss: 4.3321 - y1_output_root_mean_squared_error: 1.4737 - y2_output_root_mean_squared_error: 2.0886 - val_loss: 7.8476 - val_y1_output_loss: 2.8625 - val_y2_output_loss: 4.8289 - val_y1_output_root_mean_squared_error: 1.7036 - val_y2_output_root_mean_squared_error: 2.2238
# Epoch 53/500
# 614/614 [==============================] - 0s 127us/sample - loss: 7.7816 - y1_output_loss: 2.3519 - y2_output_loss: 5.4938 - y1_output_root_mean_squared_error: 1.5143 - y2_output_root_mean_squared_error: 2.3428 - val_loss: 24.4190 - val_y1_output_loss: 8.7668 - val_y2_output_loss: 15.0522 - val_y1_output_root_mean_squared_error: 2.9884 - val_y2_output_root_mean_squared_error: 3.9356
# Epoch 54/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.7860 - y1_output_loss: 2.2473 - y2_output_loss: 4.5606 - y1_output_root_mean_squared_error: 1.4945 - y2_output_root_mean_squared_error: 2.1337 - val_loss: 8.0333 - val_y1_output_loss: 2.2437 - val_y2_output_loss: 5.8462 - val_y1_output_root_mean_squared_error: 1.5193 - val_y2_output_root_mean_squared_error: 2.3927
# Epoch 55/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.9548 - y1_output_loss: 2.0258 - y2_output_loss: 4.9166 - y1_output_root_mean_squared_error: 1.4215 - y2_output_root_mean_squared_error: 2.2213 - val_loss: 9.0648 - val_y1_output_loss: 2.6722 - val_y2_output_loss: 6.1556 - val_y1_output_root_mean_squared_error: 1.6402 - val_y2_output_root_mean_squared_error: 2.5248
# Epoch 56/500
# 614/614 [==============================] - 0s 128us/sample - loss: 8.1178 - y1_output_loss: 2.5331 - y2_output_loss: 5.5159 - y1_output_root_mean_squared_error: 1.5979 - y2_output_root_mean_squared_error: 2.3589 - val_loss: 8.9691 - val_y1_output_loss: 2.9568 - val_y2_output_loss: 5.9524 - val_y1_output_root_mean_squared_error: 1.7368 - val_y2_output_root_mean_squared_error: 2.4398
# Epoch 57/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.1271 - y1_output_loss: 1.8067 - y2_output_loss: 4.5428 - y1_output_root_mean_squared_error: 1.3221 - y2_output_root_mean_squared_error: 2.0926 - val_loss: 35.0697 - val_y1_output_loss: 11.5142 - val_y2_output_loss: 22.6474 - val_y1_output_root_mean_squared_error: 3.4223 - val_y2_output_root_mean_squared_error: 4.8330
# Epoch 58/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.1256 - y1_output_loss: 1.8726 - y2_output_loss: 4.2647 - y1_output_root_mean_squared_error: 1.3596 - y2_output_root_mean_squared_error: 2.0681 - val_loss: 15.6453 - val_y1_output_loss: 5.1517 - val_y2_output_loss: 10.7673 - val_y1_output_root_mean_squared_error: 2.2718 - val_y2_output_root_mean_squared_error: 3.2380
# Epoch 59/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.2203 - y1_output_loss: 1.6912 - y2_output_loss: 4.4847 - y1_output_root_mean_squared_error: 1.3065 - y2_output_root_mean_squared_error: 2.1245 - val_loss: 10.2424 - val_y1_output_loss: 2.6671 - val_y2_output_loss: 7.7999 - val_y1_output_root_mean_squared_error: 1.6416 - val_y2_output_root_mean_squared_error: 2.7473
# Epoch 60/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.5285 - y1_output_loss: 1.6271 - y2_output_loss: 3.8770 - y1_output_root_mean_squared_error: 1.2809 - y2_output_root_mean_squared_error: 1.9718 - val_loss: 10.5988 - val_y1_output_loss: 2.9234 - val_y2_output_loss: 7.8553 - val_y1_output_root_mean_squared_error: 1.7155 - val_y2_output_root_mean_squared_error: 2.7669
# Epoch 61/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.7447 - y1_output_loss: 1.6495 - y2_output_loss: 4.0600 - y1_output_root_mean_squared_error: 1.2886 - y2_output_root_mean_squared_error: 2.0210 - val_loss: 8.5582 - val_y1_output_loss: 2.7981 - val_y2_output_loss: 5.7473 - val_y1_output_root_mean_squared_error: 1.6914 - val_y2_output_root_mean_squared_error: 2.3869
# Epoch 62/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.8808 - y1_output_loss: 1.7111 - y2_output_loss: 4.1230 - y1_output_root_mean_squared_error: 1.3139 - y2_output_root_mean_squared_error: 2.0383 - val_loss: 6.3721 - val_y1_output_loss: 1.7647 - val_y2_output_loss: 4.6140 - val_y1_output_root_mean_squared_error: 1.3468 - val_y2_output_root_mean_squared_error: 2.1350
# Epoch 63/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.2875 - y1_output_loss: 1.7628 - y2_output_loss: 4.5107 - y1_output_root_mean_squared_error: 1.3243 - y2_output_root_mean_squared_error: 2.1292 - val_loss: 7.6793 - val_y1_output_loss: 2.7904 - val_y2_output_loss: 4.8095 - val_y1_output_root_mean_squared_error: 1.6830 - val_y2_output_root_mean_squared_error: 2.2015
# Epoch 64/500
# 614/614 [==============================] - 0s 126us/sample - loss: 5.6993 - y1_output_loss: 1.5341 - y2_output_loss: 4.1122 - y1_output_root_mean_squared_error: 1.2441 - y2_output_root_mean_squared_error: 2.0375 - val_loss: 6.5734 - val_y1_output_loss: 1.7228 - val_y2_output_loss: 4.9618 - val_y1_output_root_mean_squared_error: 1.3184 - val_y2_output_root_mean_squared_error: 2.1989
# Epoch 65/500
# 614/614 [==============================] - 0s 126us/sample - loss: 4.8641 - y1_output_loss: 1.3449 - y2_output_loss: 3.5448 - y1_output_root_mean_squared_error: 1.1622 - y2_output_root_mean_squared_error: 1.8744 - val_loss: 13.9118 - val_y1_output_loss: 2.7416 - val_y2_output_loss: 11.4493 - val_y1_output_root_mean_squared_error: 1.6650 - val_y2_output_root_mean_squared_error: 3.3376
# Epoch 66/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.7731 - y1_output_loss: 1.2785 - y2_output_loss: 3.4707 - y1_output_root_mean_squared_error: 1.1337 - y2_output_root_mean_squared_error: 1.8676 - val_loss: 7.1423 - val_y1_output_loss: 1.9794 - val_y2_output_loss: 5.1559 - val_y1_output_root_mean_squared_error: 1.4217 - val_y2_output_root_mean_squared_error: 2.2630
# Epoch 67/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.1099 - y1_output_loss: 1.5850 - y2_output_loss: 3.5992 - y1_output_root_mean_squared_error: 1.2647 - y2_output_root_mean_squared_error: 1.8736 - val_loss: 18.7828 - val_y1_output_loss: 3.1839 - val_y2_output_loss: 15.1600 - val_y1_output_root_mean_squared_error: 1.7910 - val_y2_output_root_mean_squared_error: 3.9465
# Epoch 68/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.2565 - y1_output_loss: 1.4570 - y2_output_loss: 3.7927 - y1_output_root_mean_squared_error: 1.1974 - y2_output_root_mean_squared_error: 1.9552 - val_loss: 5.7466 - val_y1_output_loss: 1.5485 - val_y2_output_loss: 4.0836 - val_y1_output_root_mean_squared_error: 1.2596 - val_y2_output_root_mean_squared_error: 2.0396
# Epoch 69/500
# 614/614 [==============================] - 0s 127us/sample - loss: 15.0367 - y1_output_loss: 4.8842 - y2_output_loss: 10.0794 - y1_output_root_mean_squared_error: 2.2106 - y2_output_root_mean_squared_error: 3.1859 - val_loss: 8.8042 - val_y1_output_loss: 2.8426 - val_y2_output_loss: 5.9915 - val_y1_output_root_mean_squared_error: 1.6990 - val_y2_output_root_mean_squared_error: 2.4326
# Epoch 70/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.9220 - y1_output_loss: 1.4223 - y2_output_loss: 3.5280 - y1_output_root_mean_squared_error: 1.1887 - y2_output_root_mean_squared_error: 1.8732 - val_loss: 6.5492 - val_y1_output_loss: 1.6128 - val_y2_output_loss: 4.7496 - val_y1_output_root_mean_squared_error: 1.2825 - val_y2_output_root_mean_squared_error: 2.2146
# Epoch 71/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.6345 - y1_output_loss: 1.2801 - y2_output_loss: 3.3630 - y1_output_root_mean_squared_error: 1.1351 - y2_output_root_mean_squared_error: 1.8292 - val_loss: 6.1957 - val_y1_output_loss: 1.9096 - val_y2_output_loss: 4.2660 - val_y1_output_root_mean_squared_error: 1.3856 - val_y2_output_root_mean_squared_error: 2.0678
# Epoch 72/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.4004 - y1_output_loss: 1.2266 - y2_output_loss: 3.1436 - y1_output_root_mean_squared_error: 1.1116 - y2_output_root_mean_squared_error: 1.7790 - val_loss: 5.6799 - val_y1_output_loss: 1.4661 - val_y2_output_loss: 4.0716 - val_y1_output_root_mean_squared_error: 1.2228 - val_y2_output_root_mean_squared_error: 2.0456
# Epoch 73/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.7507 - y1_output_loss: 1.2291 - y2_output_loss: 3.5403 - y1_output_root_mean_squared_error: 1.1131 - y2_output_root_mean_squared_error: 1.8739 - val_loss: 8.9647 - val_y1_output_loss: 2.9743 - val_y2_output_loss: 6.0780 - val_y1_output_root_mean_squared_error: 1.7343 - val_y2_output_root_mean_squared_error: 2.4407
# Epoch 74/500
# 614/614 [==============================] - 0s 138us/sample - loss: 6.5027 - y1_output_loss: 1.8497 - y2_output_loss: 4.6616 - y1_output_root_mean_squared_error: 1.3662 - y2_output_root_mean_squared_error: 2.1532 - val_loss: 6.1845 - val_y1_output_loss: 1.4290 - val_y2_output_loss: 4.5969 - val_y1_output_root_mean_squared_error: 1.2106 - val_y2_output_root_mean_squared_error: 2.1723
# Epoch 75/500
# 614/614 [==============================] - 0s 137us/sample - loss: 5.4872 - y1_output_loss: 1.2932 - y2_output_loss: 4.1682 - y1_output_root_mean_squared_error: 1.1408 - y2_output_root_mean_squared_error: 2.0459 - val_loss: 6.9919 - val_y1_output_loss: 2.2778 - val_y2_output_loss: 4.6950 - val_y1_output_root_mean_squared_error: 1.5210 - val_y2_output_root_mean_squared_error: 2.1630
# Epoch 76/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.8380 - y1_output_loss: 1.3009 - y2_output_loss: 3.5880 - y1_output_root_mean_squared_error: 1.1277 - y2_output_root_mean_squared_error: 1.8885 - val_loss: 16.1857 - val_y1_output_loss: 4.0696 - val_y2_output_loss: 11.8084 - val_y1_output_root_mean_squared_error: 2.0215 - val_y2_output_root_mean_squared_error: 3.4784
# Epoch 77/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.8413 - y1_output_loss: 1.2421 - y2_output_loss: 3.7081 - y1_output_root_mean_squared_error: 1.1168 - y2_output_root_mean_squared_error: 1.8958 - val_loss: 9.3224 - val_y1_output_loss: 1.3489 - val_y2_output_loss: 8.1939 - val_y1_output_root_mean_squared_error: 1.1765 - val_y2_output_root_mean_squared_error: 2.8175
# Epoch 78/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.1585 - y1_output_loss: 1.0613 - y2_output_loss: 3.0717 - y1_output_root_mean_squared_error: 1.0305 - y2_output_root_mean_squared_error: 1.7597 - val_loss: 4.5367 - val_y1_output_loss: 1.1202 - val_y2_output_loss: 3.4130 - val_y1_output_root_mean_squared_error: 1.0723 - val_y2_output_root_mean_squared_error: 1.8404
# Epoch 79/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.3878 - y1_output_loss: 0.8239 - y2_output_loss: 2.5889 - y1_output_root_mean_squared_error: 0.9000 - y2_output_root_mean_squared_error: 1.6056 - val_loss: 11.0710 - val_y1_output_loss: 1.7290 - val_y2_output_loss: 9.0255 - val_y1_output_root_mean_squared_error: 1.3304 - val_y2_output_root_mean_squared_error: 3.0498
# Epoch 80/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.7526 - y1_output_loss: 0.8962 - y2_output_loss: 2.8353 - y1_output_root_mean_squared_error: 0.9488 - y2_output_root_mean_squared_error: 1.6889 - val_loss: 4.9581 - val_y1_output_loss: 1.1568 - val_y2_output_loss: 3.6948 - val_y1_output_root_mean_squared_error: 1.0848 - val_y2_output_root_mean_squared_error: 1.9445
# Epoch 81/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.0178 - y1_output_loss: 0.9698 - y2_output_loss: 3.0102 - y1_output_root_mean_squared_error: 0.9892 - y2_output_root_mean_squared_error: 1.7434 - val_loss: 4.8190 - val_y1_output_loss: 1.2155 - val_y2_output_loss: 3.6098 - val_y1_output_root_mean_squared_error: 1.1141 - val_y2_output_root_mean_squared_error: 1.8915
# Epoch 82/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.5618 - y1_output_loss: 0.8756 - y2_output_loss: 2.6662 - y1_output_root_mean_squared_error: 0.9358 - y2_output_root_mean_squared_error: 1.6389 - val_loss: 5.4897 - val_y1_output_loss: 1.3633 - val_y2_output_loss: 4.1998 - val_y1_output_root_mean_squared_error: 1.1757 - val_y2_output_root_mean_squared_error: 2.0267
# Epoch 83/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.0055 - y1_output_loss: 0.8953 - y2_output_loss: 3.0761 - y1_output_root_mean_squared_error: 0.9487 - y2_output_root_mean_squared_error: 1.7622 - val_loss: 4.7205 - val_y1_output_loss: 1.3904 - val_y2_output_loss: 3.3507 - val_y1_output_root_mean_squared_error: 1.1875 - val_y2_output_root_mean_squared_error: 1.8195
# Epoch 84/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.0340 - y1_output_loss: 0.9043 - y2_output_loss: 3.1401 - y1_output_root_mean_squared_error: 0.9495 - y2_output_root_mean_squared_error: 1.7699 - val_loss: 12.5247 - val_y1_output_loss: 2.6495 - val_y2_output_loss: 10.1150 - val_y1_output_root_mean_squared_error: 1.6396 - val_y2_output_root_mean_squared_error: 3.1363
# Epoch 85/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.4663 - y1_output_loss: 0.8648 - y2_output_loss: 2.6019 - y1_output_root_mean_squared_error: 0.9321 - y2_output_root_mean_squared_error: 1.6117 - val_loss: 5.1055 - val_y1_output_loss: 1.2933 - val_y2_output_loss: 3.8512 - val_y1_output_root_mean_squared_error: 1.1579 - val_y2_output_root_mean_squared_error: 1.9403
# Epoch 86/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.3486 - y1_output_loss: 0.9491 - y2_output_loss: 2.4294 - y1_output_root_mean_squared_error: 0.9740 - y2_output_root_mean_squared_error: 1.5492 - val_loss: 18.8009 - val_y1_output_loss: 2.4358 - val_y2_output_loss: 16.8394 - val_y1_output_root_mean_squared_error: 1.5633 - val_y2_output_root_mean_squared_error: 4.0444
# Epoch 87/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.4288 - y1_output_loss: 0.8634 - y2_output_loss: 2.5683 - y1_output_root_mean_squared_error: 0.9284 - y2_output_root_mean_squared_error: 1.6022 - val_loss: 4.5490 - val_y1_output_loss: 1.4137 - val_y2_output_loss: 3.1259 - val_y1_output_root_mean_squared_error: 1.1940 - val_y2_output_root_mean_squared_error: 1.7673
# Epoch 88/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.9111 - y1_output_loss: 1.4578 - y2_output_loss: 3.4320 - y1_output_root_mean_squared_error: 1.2044 - y2_output_root_mean_squared_error: 1.8602 - val_loss: 4.1123 - val_y1_output_loss: 0.9469 - val_y2_output_loss: 3.1750 - val_y1_output_root_mean_squared_error: 0.9874 - val_y2_output_root_mean_squared_error: 1.7713
# Epoch 89/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.5860 - y1_output_loss: 0.9001 - y2_output_loss: 2.6580 - y1_output_root_mean_squared_error: 0.9515 - y2_output_root_mean_squared_error: 1.6373 - val_loss: 4.5495 - val_y1_output_loss: 0.9796 - val_y2_output_loss: 3.6556 - val_y1_output_root_mean_squared_error: 1.0057 - val_y2_output_root_mean_squared_error: 1.8810
# Epoch 90/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.9119 - y1_output_loss: 0.9576 - y2_output_loss: 2.9207 - y1_output_root_mean_squared_error: 0.9823 - y2_output_root_mean_squared_error: 1.7167 - val_loss: 3.9998 - val_y1_output_loss: 0.8296 - val_y2_output_loss: 3.2383 - val_y1_output_root_mean_squared_error: 0.9260 - val_y2_output_root_mean_squared_error: 1.7727
# Epoch 91/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.2630 - y1_output_loss: 1.0510 - y2_output_loss: 3.1980 - y1_output_root_mean_squared_error: 1.0185 - y2_output_root_mean_squared_error: 1.7960 - val_loss: 4.7627 - val_y1_output_loss: 1.4222 - val_y2_output_loss: 3.3914 - val_y1_output_root_mean_squared_error: 1.2014 - val_y2_output_root_mean_squared_error: 1.8219
# Epoch 92/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.9944 - y1_output_loss: 0.7383 - y2_output_loss: 2.2471 - y1_output_root_mean_squared_error: 0.8557 - y2_output_root_mean_squared_error: 1.5040 - val_loss: 3.4609 - val_y1_output_loss: 0.8261 - val_y2_output_loss: 2.6435 - val_y1_output_root_mean_squared_error: 0.9223 - val_y2_output_root_mean_squared_error: 1.6156
# Epoch 93/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.9443 - y1_output_loss: 0.6685 - y2_output_loss: 2.2571 - y1_output_root_mean_squared_error: 0.8202 - y2_output_root_mean_squared_error: 1.5072 - val_loss: 4.8822 - val_y1_output_loss: 1.3285 - val_y2_output_loss: 3.5430 - val_y1_output_root_mean_squared_error: 1.1697 - val_y2_output_root_mean_squared_error: 1.8746
# Epoch 94/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.7374 - y1_output_loss: 0.9112 - y2_output_loss: 2.8441 - y1_output_root_mean_squared_error: 0.9507 - y2_output_root_mean_squared_error: 1.6833 - val_loss: 15.6640 - val_y1_output_loss: 5.6014 - val_y2_output_loss: 9.9129 - val_y1_output_root_mean_squared_error: 2.4042 - val_y2_output_root_mean_squared_error: 3.1438
# Epoch 95/500
# 614/614 [==============================] - 0s 134us/sample - loss: 8.6224 - y1_output_loss: 2.6033 - y2_output_loss: 5.9468 - y1_output_root_mean_squared_error: 1.6186 - y2_output_root_mean_squared_error: 2.4500 - val_loss: 4.2605 - val_y1_output_loss: 1.1251 - val_y2_output_loss: 3.1464 - val_y1_output_root_mean_squared_error: 1.0732 - val_y2_output_root_mean_squared_error: 1.7632
# Epoch 96/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.0114 - y1_output_loss: 0.7283 - y2_output_loss: 2.3037 - y1_output_root_mean_squared_error: 0.8552 - y2_output_root_mean_squared_error: 1.5100 - val_loss: 9.7380 - val_y1_output_loss: 1.0923 - val_y2_output_loss: 8.9792 - val_y1_output_root_mean_squared_error: 1.0558 - val_y2_output_root_mean_squared_error: 2.9365
# Epoch 97/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.7818 - y1_output_loss: 0.9277 - y2_output_loss: 2.8228 - y1_output_root_mean_squared_error: 0.9668 - y2_output_root_mean_squared_error: 1.6873 - val_loss: 6.6332 - val_y1_output_loss: 1.8888 - val_y2_output_loss: 4.8608 - val_y1_output_root_mean_squared_error: 1.3936 - val_y2_output_root_mean_squared_error: 2.1659
# Epoch 98/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.1680 - y1_output_loss: 0.7558 - y2_output_loss: 2.3866 - y1_output_root_mean_squared_error: 0.8725 - y2_output_root_mean_squared_error: 1.5514 - val_loss: 3.5076 - val_y1_output_loss: 0.7020 - val_y2_output_loss: 2.8350 - val_y1_output_root_mean_squared_error: 0.8477 - val_y2_output_root_mean_squared_error: 1.6701
# Epoch 99/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.1793 - y1_output_loss: 0.7033 - y2_output_loss: 2.4645 - y1_output_root_mean_squared_error: 0.8404 - y2_output_root_mean_squared_error: 1.5726 - val_loss: 3.9823 - val_y1_output_loss: 0.9984 - val_y2_output_loss: 3.0058 - val_y1_output_root_mean_squared_error: 1.0127 - val_y2_output_root_mean_squared_error: 1.7195
# Epoch 100/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.8313 - y1_output_loss: 0.6027 - y2_output_loss: 2.2029 - y1_output_root_mean_squared_error: 0.7800 - y2_output_root_mean_squared_error: 1.4909 - val_loss: 3.3219 - val_y1_output_loss: 0.6777 - val_y2_output_loss: 2.6912 - val_y1_output_root_mean_squared_error: 0.8280 - val_y2_output_root_mean_squared_error: 1.6237
# Epoch 101/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.4680 - y1_output_loss: 0.8845 - y2_output_loss: 2.5874 - y1_output_root_mean_squared_error: 0.9354 - y2_output_root_mean_squared_error: 1.6103 - val_loss: 7.7789 - val_y1_output_loss: 2.4184 - val_y2_output_loss: 5.1658 - val_y1_output_root_mean_squared_error: 1.5707 - val_y2_output_root_mean_squared_error: 2.3047
# Epoch 102/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.7950 - y1_output_loss: 0.6439 - y2_output_loss: 2.1342 - y1_output_root_mean_squared_error: 0.8055 - y2_output_root_mean_squared_error: 1.4650 - val_loss: 4.3711 - val_y1_output_loss: 1.2240 - val_y2_output_loss: 3.1277 - val_y1_output_root_mean_squared_error: 1.1145 - val_y2_output_root_mean_squared_error: 1.7689
# Epoch 103/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.9079 - y1_output_loss: 0.7228 - y2_output_loss: 2.2023 - y1_output_root_mean_squared_error: 0.8492 - y2_output_root_mean_squared_error: 1.4788 - val_loss: 3.5904 - val_y1_output_loss: 1.1564 - val_y2_output_loss: 2.3820 - val_y1_output_root_mean_squared_error: 1.0810 - val_y2_output_root_mean_squared_error: 1.5562
# Epoch 104/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.4119 - y1_output_loss: 0.5413 - y2_output_loss: 1.8547 - y1_output_root_mean_squared_error: 0.7375 - y2_output_root_mean_squared_error: 1.3667 - val_loss: 4.0527 - val_y1_output_loss: 0.7776 - val_y2_output_loss: 3.2281 - val_y1_output_root_mean_squared_error: 0.8946 - val_y2_output_root_mean_squared_error: 1.8034
# Epoch 105/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.8871 - y1_output_loss: 0.6137 - y2_output_loss: 2.3126 - y1_output_root_mean_squared_error: 0.7825 - y2_output_root_mean_squared_error: 1.5082 - val_loss: 11.1823 - val_y1_output_loss: 3.1983 - val_y2_output_loss: 7.6964 - val_y1_output_root_mean_squared_error: 1.8056 - val_y2_output_root_mean_squared_error: 2.8147
# Epoch 106/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.1638 - y1_output_loss: 0.7228 - y2_output_loss: 2.4464 - y1_output_root_mean_squared_error: 0.8502 - y2_output_root_mean_squared_error: 1.5623 - val_loss: 4.4856 - val_y1_output_loss: 0.9033 - val_y2_output_loss: 3.6502 - val_y1_output_root_mean_squared_error: 0.9669 - val_y2_output_root_mean_squared_error: 1.8843
# Epoch 107/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.6887 - y1_output_loss: 0.9570 - y2_output_loss: 2.7211 - y1_output_root_mean_squared_error: 0.9815 - y2_output_root_mean_squared_error: 1.6509 - val_loss: 4.8234 - val_y1_output_loss: 1.2159 - val_y2_output_loss: 3.5240 - val_y1_output_root_mean_squared_error: 1.1132 - val_y2_output_root_mean_squared_error: 1.8932
# Epoch 108/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.9371 - y1_output_loss: 0.6168 - y2_output_loss: 2.3323 - y1_output_root_mean_squared_error: 0.7868 - y2_output_root_mean_squared_error: 1.5225 - val_loss: 3.2035 - val_y1_output_loss: 0.6911 - val_y2_output_loss: 2.5111 - val_y1_output_root_mean_squared_error: 0.8388 - val_y2_output_root_mean_squared_error: 1.5812
# Epoch 109/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.3332 - y1_output_loss: 0.5840 - y2_output_loss: 1.7740 - y1_output_root_mean_squared_error: 0.7571 - y2_output_root_mean_squared_error: 1.3266 - val_loss: 3.4280 - val_y1_output_loss: 0.7586 - val_y2_output_loss: 2.7556 - val_y1_output_root_mean_squared_error: 0.8764 - val_y2_output_root_mean_squared_error: 1.6309
# Epoch 110/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.4127 - y1_output_loss: 0.9344 - y2_output_loss: 3.4401 - y1_output_root_mean_squared_error: 0.9693 - y2_output_root_mean_squared_error: 1.8636 - val_loss: 3.2992 - val_y1_output_loss: 0.7508 - val_y2_output_loss: 2.5284 - val_y1_output_root_mean_squared_error: 0.8728 - val_y2_output_root_mean_squared_error: 1.5929
# Epoch 111/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.3533 - y1_output_loss: 0.7375 - y2_output_loss: 2.6153 - y1_output_root_mean_squared_error: 0.8520 - y2_output_root_mean_squared_error: 1.6209 - val_loss: 5.6569 - val_y1_output_loss: 1.4454 - val_y2_output_loss: 4.3106 - val_y1_output_root_mean_squared_error: 1.2097 - val_y2_output_root_mean_squared_error: 2.0478
# Epoch 112/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.7665 - y1_output_loss: 0.5919 - y2_output_loss: 2.1640 - y1_output_root_mean_squared_error: 0.7671 - y2_output_root_mean_squared_error: 1.4758 - val_loss: 5.9474 - val_y1_output_loss: 2.3932 - val_y2_output_loss: 3.4162 - val_y1_output_root_mean_squared_error: 1.5573 - val_y2_output_root_mean_squared_error: 1.8768
# Epoch 113/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.1336 - y1_output_loss: 0.8293 - y2_output_loss: 2.2920 - y1_output_root_mean_squared_error: 0.9125 - y2_output_root_mean_squared_error: 1.5169 - val_loss: 3.9533 - val_y1_output_loss: 0.9116 - val_y2_output_loss: 3.0695 - val_y1_output_root_mean_squared_error: 0.9702 - val_y2_output_root_mean_squared_error: 1.7355
# Epoch 114/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.8324 - y1_output_loss: 0.6953 - y2_output_loss: 2.1379 - y1_output_root_mean_squared_error: 0.8339 - y2_output_root_mean_squared_error: 1.4619 - val_loss: 4.6409 - val_y1_output_loss: 0.7088 - val_y2_output_loss: 4.0528 - val_y1_output_root_mean_squared_error: 0.8469 - val_y2_output_root_mean_squared_error: 1.9808
# Epoch 115/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.1252 - y1_output_loss: 0.6903 - y2_output_loss: 2.4231 - y1_output_root_mean_squared_error: 0.8326 - y2_output_root_mean_squared_error: 1.5595 - val_loss: 2.7368 - val_y1_output_loss: 0.6533 - val_y2_output_loss: 2.0604 - val_y1_output_root_mean_squared_error: 0.8151 - val_y2_output_root_mean_squared_error: 1.4396
# Epoch 116/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.4536 - y1_output_loss: 0.5420 - y2_output_loss: 1.8995 - y1_output_root_mean_squared_error: 0.7354 - y2_output_root_mean_squared_error: 1.3831 - val_loss: 2.9905 - val_y1_output_loss: 0.5073 - val_y2_output_loss: 2.5584 - val_y1_output_root_mean_squared_error: 0.7199 - val_y2_output_root_mean_squared_error: 1.5723
# Epoch 117/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.2572 - y1_output_loss: 0.5147 - y2_output_loss: 1.7436 - y1_output_root_mean_squared_error: 0.7065 - y2_output_root_mean_squared_error: 1.3259 - val_loss: 3.7284 - val_y1_output_loss: 1.1645 - val_y2_output_loss: 2.5823 - val_y1_output_root_mean_squared_error: 1.0821 - val_y2_output_root_mean_squared_error: 1.5992
# Epoch 118/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.6484 - y1_output_loss: 0.5940 - y2_output_loss: 2.0349 - y1_output_root_mean_squared_error: 0.7714 - y2_output_root_mean_squared_error: 1.4330 - val_loss: 2.8337 - val_y1_output_loss: 0.4850 - val_y2_output_loss: 2.3971 - val_y1_output_root_mean_squared_error: 0.7010 - val_y2_output_root_mean_squared_error: 1.5305
# Epoch 119/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.5831 - y1_output_loss: 0.5845 - y2_output_loss: 1.9823 - y1_output_root_mean_squared_error: 0.7676 - y2_output_root_mean_squared_error: 1.4120 - val_loss: 2.5198 - val_y1_output_loss: 0.5465 - val_y2_output_loss: 1.9649 - val_y1_output_root_mean_squared_error: 0.7437 - val_y2_output_root_mean_squared_error: 1.4024
# Epoch 120/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.1990 - y1_output_loss: 0.4814 - y2_output_loss: 1.7086 - y1_output_root_mean_squared_error: 0.6949 - y2_output_root_mean_squared_error: 1.3100 - val_loss: 3.3271 - val_y1_output_loss: 0.8411 - val_y2_output_loss: 2.4875 - val_y1_output_root_mean_squared_error: 0.9185 - val_y2_output_root_mean_squared_error: 1.5759
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3053 - y1_output_loss: 0.0993 - y2_output_loss: 0.2139 - y1_output_root_mean_squared_error: 0.3157 - y2_output_root_mean_squared_error: 0.4535 - val_loss: 1.7811 - val_y1_output_loss: 0.2889 - val_y2_output_loss: 1.5062 - val_y1_output_root_mean_squared_error: 0.5467 - val_y2_output_root_mean_squared_error: 1.2174
# Epoch 462/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3957 - y1_output_loss: 0.1260 - y2_output_loss: 0.2664 - y1_output_root_mean_squared_error: 0.3563 - y2_output_root_mean_squared_error: 0.5184 - val_loss: 0.9340 - val_y1_output_loss: 0.2284 - val_y2_output_loss: 0.6913 - val_y1_output_root_mean_squared_error: 0.4841 - val_y2_output_root_mean_squared_error: 0.8364
# Epoch 463/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3653 - y1_output_loss: 0.1224 - y2_output_loss: 0.2397 - y1_output_root_mean_squared_error: 0.3513 - y2_output_root_mean_squared_error: 0.4918 - val_loss: 0.8285 - val_y1_output_loss: 0.2220 - val_y2_output_loss: 0.5933 - val_y1_output_root_mean_squared_error: 0.4791 - val_y2_output_root_mean_squared_error: 0.7739
# Epoch 464/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3694 - y1_output_loss: 0.1216 - y2_output_loss: 0.2494 - y1_output_root_mean_squared_error: 0.3453 - y2_output_root_mean_squared_error: 0.5001 - val_loss: 0.9839 - val_y1_output_loss: 0.2418 - val_y2_output_loss: 0.7284 - val_y1_output_root_mean_squared_error: 0.4996 - val_y2_output_root_mean_squared_error: 0.8569
# Epoch 465/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4038 - y1_output_loss: 0.1298 - y2_output_loss: 0.2723 - y1_output_root_mean_squared_error: 0.3601 - y2_output_root_mean_squared_error: 0.5236 - val_loss: 0.7953 - val_y1_output_loss: 0.2575 - val_y2_output_loss: 0.5335 - val_y1_output_root_mean_squared_error: 0.5111 - val_y2_output_root_mean_squared_error: 0.7308
# Epoch 466/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3809 - y1_output_loss: 0.1111 - y2_output_loss: 0.2675 - y1_output_root_mean_squared_error: 0.3336 - y2_output_root_mean_squared_error: 0.5192 - val_loss: 0.8367 - val_y1_output_loss: 0.2423 - val_y2_output_loss: 0.5948 - val_y1_output_root_mean_squared_error: 0.4988 - val_y2_output_root_mean_squared_error: 0.7667
# Epoch 467/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4191 - y1_output_loss: 0.1249 - y2_output_loss: 0.2980 - y1_output_root_mean_squared_error: 0.3523 - y2_output_root_mean_squared_error: 0.5431 - val_loss: 1.1007 - val_y1_output_loss: 0.3941 - val_y2_output_loss: 0.6921 - val_y1_output_root_mean_squared_error: 0.6375 - val_y2_output_root_mean_squared_error: 0.8332
# Epoch 468/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3629 - y1_output_loss: 0.1182 - y2_output_loss: 0.2431 - y1_output_root_mean_squared_error: 0.3442 - y2_output_root_mean_squared_error: 0.4943 - val_loss: 1.0096 - val_y1_output_loss: 0.2570 - val_y2_output_loss: 0.7662 - val_y1_output_root_mean_squared_error: 0.5136 - val_y2_output_root_mean_squared_error: 0.8636
# Epoch 469/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4910 - y1_output_loss: 0.1350 - y2_output_loss: 0.3544 - y1_output_root_mean_squared_error: 0.3657 - y2_output_root_mean_squared_error: 0.5977 - val_loss: 0.9081 - val_y1_output_loss: 0.2615 - val_y2_output_loss: 0.6387 - val_y1_output_root_mean_squared_error: 0.5175 - val_y2_output_root_mean_squared_error: 0.8001
# Epoch 470/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4187 - y1_output_loss: 0.1310 - y2_output_loss: 0.2846 - y1_output_root_mean_squared_error: 0.3635 - y2_output_root_mean_squared_error: 0.5353 - val_loss: 0.8956 - val_y1_output_loss: 0.2200 - val_y2_output_loss: 0.6735 - val_y1_output_root_mean_squared_error: 0.4759 - val_y2_output_root_mean_squared_error: 0.8180
# Epoch 471/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3410 - y1_output_loss: 0.1056 - y2_output_loss: 0.2364 - y1_output_root_mean_squared_error: 0.3230 - y2_output_root_mean_squared_error: 0.4864 - val_loss: 1.7096 - val_y1_output_loss: 0.5171 - val_y2_output_loss: 1.1570 - val_y1_output_root_mean_squared_error: 0.7263 - val_y2_output_root_mean_squared_error: 1.0873
# Epoch 472/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3177 - y1_output_loss: 0.1071 - y2_output_loss: 0.2088 - y1_output_root_mean_squared_error: 0.3282 - y2_output_root_mean_squared_error: 0.4583 - val_loss: 0.8559 - val_y1_output_loss: 0.2351 - val_y2_output_loss: 0.6320 - val_y1_output_root_mean_squared_error: 0.4926 - val_y2_output_root_mean_squared_error: 0.7831
# Epoch 473/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4719 - y1_output_loss: 0.1332 - y2_output_loss: 0.3428 - y1_output_root_mean_squared_error: 0.3640 - y2_output_root_mean_squared_error: 0.5826 - val_loss: 1.2822 - val_y1_output_loss: 0.3258 - val_y2_output_loss: 0.9331 - val_y1_output_root_mean_squared_error: 0.5797 - val_y2_output_root_mean_squared_error: 0.9727
# Epoch 474/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4189 - y1_output_loss: 0.1183 - y2_output_loss: 0.2982 - y1_output_root_mean_squared_error: 0.3444 - y2_output_root_mean_squared_error: 0.5480 - val_loss: 0.8612 - val_y1_output_loss: 0.2209 - val_y2_output_loss: 0.6385 - val_y1_output_root_mean_squared_error: 0.4760 - val_y2_output_root_mean_squared_error: 0.7966
# Epoch 475/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.5272 - y1_output_loss: 0.1368 - y2_output_loss: 0.3894 - y1_output_root_mean_squared_error: 0.3707 - y2_output_root_mean_squared_error: 0.6244 - val_loss: 0.9025 - val_y1_output_loss: 0.2499 - val_y2_output_loss: 0.6632 - val_y1_output_root_mean_squared_error: 0.5036 - val_y2_output_root_mean_squared_error: 0.8055
# Epoch 476/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4079 - y1_output_loss: 0.1253 - y2_output_loss: 0.2815 - y1_output_root_mean_squared_error: 0.3551 - y2_output_root_mean_squared_error: 0.5309 - val_loss: 1.1246 - val_y1_output_loss: 0.2830 - val_y2_output_loss: 0.8438 - val_y1_output_root_mean_squared_error: 0.5384 - val_y2_output_root_mean_squared_error: 0.9137
# Epoch 477/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.5866 - y1_output_loss: 0.1421 - y2_output_loss: 0.4525 - y1_output_root_mean_squared_error: 0.3773 - y2_output_root_mean_squared_error: 0.6665 - val_loss: 1.5003 - val_y1_output_loss: 0.4045 - val_y2_output_loss: 1.0671 - val_y1_output_root_mean_squared_error: 0.6442 - val_y2_output_root_mean_squared_error: 1.0418
# Epoch 478/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.8226 - y1_output_loss: 0.2027 - y2_output_loss: 0.6201 - y1_output_root_mean_squared_error: 0.4513 - y2_output_root_mean_squared_error: 0.7867 - val_loss: 1.1694 - val_y1_output_loss: 0.3134 - val_y2_output_loss: 0.8252 - val_y1_output_root_mean_squared_error: 0.5668 - val_y2_output_root_mean_squared_error: 0.9209
# Epoch 479/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4583 - y1_output_loss: 0.1276 - y2_output_loss: 0.3271 - y1_output_root_mean_squared_error: 0.3587 - y2_output_root_mean_squared_error: 0.5741 - val_loss: 0.8705 - val_y1_output_loss: 0.2346 - val_y2_output_loss: 0.6279 - val_y1_output_root_mean_squared_error: 0.4893 - val_y2_output_root_mean_squared_error: 0.7944
# Epoch 480/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4686 - y1_output_loss: 0.1307 - y2_output_loss: 0.3355 - y1_output_root_mean_squared_error: 0.3612 - y2_output_root_mean_squared_error: 0.5815 - val_loss: 1.0554 - val_y1_output_loss: 0.2778 - val_y2_output_loss: 0.7799 - val_y1_output_root_mean_squared_error: 0.5367 - val_y2_output_root_mean_squared_error: 0.8760
# Epoch 481/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3772 - y1_output_loss: 0.1227 - y2_output_loss: 0.2532 - y1_output_root_mean_squared_error: 0.3511 - y2_output_root_mean_squared_error: 0.5039 - val_loss: 1.0984 - val_y1_output_loss: 0.3492 - val_y2_output_loss: 0.7326 - val_y1_output_root_mean_squared_error: 0.5960 - val_y2_output_root_mean_squared_error: 0.8621
# Epoch 482/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.5757 - y1_output_loss: 0.1277 - y2_output_loss: 0.4443 - y1_output_root_mean_squared_error: 0.3583 - y2_output_root_mean_squared_error: 0.6688 - val_loss: 0.9791 - val_y1_output_loss: 0.2296 - val_y2_output_loss: 0.7572 - val_y1_output_root_mean_squared_error: 0.4862 - val_y2_output_root_mean_squared_error: 0.8618
# Epoch 483/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.5647 - y1_output_loss: 0.1523 - y2_output_loss: 0.4307 - y1_output_root_mean_squared_error: 0.3829 - y2_output_root_mean_squared_error: 0.6466 - val_loss: 6.3495 - val_y1_output_loss: 2.0460 - val_y2_output_loss: 4.2244 - val_y1_output_root_mean_squared_error: 1.4531 - val_y2_output_root_mean_squared_error: 2.0587
# Epoch 484/500
# 614/614 [==============================] - 0s 127us/sample - loss: 1.5276 - y1_output_loss: 0.2922 - y2_output_loss: 1.2291 - y1_output_root_mean_squared_error: 0.5410 - y2_output_root_mean_squared_error: 1.1113 - val_loss: 1.3610 - val_y1_output_loss: 0.3618 - val_y2_output_loss: 0.9872 - val_y1_output_root_mean_squared_error: 0.6042 - val_y2_output_root_mean_squared_error: 0.9980
# Epoch 485/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4181 - y1_output_loss: 0.1157 - y2_output_loss: 0.2993 - y1_output_root_mean_squared_error: 0.3411 - y2_output_root_mean_squared_error: 0.5493 - val_loss: 0.8135 - val_y1_output_loss: 0.2442 - val_y2_output_loss: 0.5711 - val_y1_output_root_mean_squared_error: 0.4968 - val_y2_output_root_mean_squared_error: 0.7528
# Epoch 486/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3403 - y1_output_loss: 0.1092 - y2_output_loss: 0.2309 - y1_output_root_mean_squared_error: 0.3293 - y2_output_root_mean_squared_error: 0.4815 - val_loss: 1.1009 - val_y1_output_loss: 0.3454 - val_y2_output_loss: 0.7421 - val_y1_output_root_mean_squared_error: 0.5915 - val_y2_output_root_mean_squared_error: 0.8666
# Epoch 487/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.5173 - y1_output_loss: 0.1423 - y2_output_loss: 0.3731 - y1_output_root_mean_squared_error: 0.3785 - y2_output_root_mean_squared_error: 0.6116 - val_loss: 1.1203 - val_y1_output_loss: 0.2342 - val_y2_output_loss: 0.8934 - val_y1_output_root_mean_squared_error: 0.4900 - val_y2_output_root_mean_squared_error: 0.9382
# Epoch 488/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3808 - y1_output_loss: 0.1228 - y2_output_loss: 0.2552 - y1_output_root_mean_squared_error: 0.3517 - y2_output_root_mean_squared_error: 0.5070 - val_loss: 0.8585 - val_y1_output_loss: 0.2106 - val_y2_output_loss: 0.6360 - val_y1_output_root_mean_squared_error: 0.4653 - val_y2_output_root_mean_squared_error: 0.8012
# Epoch 489/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.2829 - y1_output_loss: 0.1058 - y2_output_loss: 0.1774 - y1_output_root_mean_squared_error: 0.3240 - y2_output_root_mean_squared_error: 0.4218 - val_loss: 0.8078 - val_y1_output_loss: 0.2150 - val_y2_output_loss: 0.5842 - val_y1_output_root_mean_squared_error: 0.4718 - val_y2_output_root_mean_squared_error: 0.7650
# Epoch 490/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3061 - y1_output_loss: 0.1004 - y2_output_loss: 0.2070 - y1_output_root_mean_squared_error: 0.3173 - y2_output_root_mean_squared_error: 0.4533 - val_loss: 1.2530 - val_y1_output_loss: 0.2907 - val_y2_output_loss: 0.9600 - val_y1_output_root_mean_squared_error: 0.5435 - val_y2_output_root_mean_squared_error: 0.9785
# Epoch 491/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3259 - y1_output_loss: 0.1096 - y2_output_loss: 0.2156 - y1_output_root_mean_squared_error: 0.3307 - y2_output_root_mean_squared_error: 0.4654 - val_loss: 0.9514 - val_y1_output_loss: 0.2423 - val_y2_output_loss: 0.7188 - val_y1_output_root_mean_squared_error: 0.5014 - val_y2_output_root_mean_squared_error: 0.8367
# Epoch 492/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3371 - y1_output_loss: 0.1110 - y2_output_loss: 0.2252 - y1_output_root_mean_squared_error: 0.3338 - y2_output_root_mean_squared_error: 0.4751 - val_loss: 0.8382 - val_y1_output_loss: 0.2214 - val_y2_output_loss: 0.6171 - val_y1_output_root_mean_squared_error: 0.4790 - val_y2_output_root_mean_squared_error: 0.7802
# Epoch 493/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3706 - y1_output_loss: 0.1107 - y2_output_loss: 0.2636 - y1_output_root_mean_squared_error: 0.3291 - y2_output_root_mean_squared_error: 0.5122 - val_loss: 1.2088 - val_y1_output_loss: 0.3458 - val_y2_output_loss: 0.8765 - val_y1_output_root_mean_squared_error: 0.5978 - val_y2_output_root_mean_squared_error: 0.9227
# Epoch 494/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3796 - y1_output_loss: 0.1232 - y2_output_loss: 0.2545 - y1_output_root_mean_squared_error: 0.3518 - y2_output_root_mean_squared_error: 0.5058 - val_loss: 0.8593 - val_y1_output_loss: 0.2429 - val_y2_output_loss: 0.6207 - val_y1_output_root_mean_squared_error: 0.4951 - val_y2_output_root_mean_squared_error: 0.7837
# Epoch 495/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3952 - y1_output_loss: 0.1305 - y2_output_loss: 0.2635 - y1_output_root_mean_squared_error: 0.3618 - y2_output_root_mean_squared_error: 0.5141 - val_loss: 1.1170 - val_y1_output_loss: 0.2257 - val_y2_output_loss: 0.8928 - val_y1_output_root_mean_squared_error: 0.4834 - val_y2_output_root_mean_squared_error: 0.9399
# Epoch 496/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3143 - y1_output_loss: 0.1139 - y2_output_loss: 0.1984 - y1_output_root_mean_squared_error: 0.3389 - y2_output_root_mean_squared_error: 0.4467 - val_loss: 0.8567 - val_y1_output_loss: 0.2668 - val_y2_output_loss: 0.5810 - val_y1_output_root_mean_squared_error: 0.5221 - val_y2_output_root_mean_squared_error: 0.7642
# Epoch 497/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3668 - y1_output_loss: 0.1278 - y2_output_loss: 0.2365 - y1_output_root_mean_squared_error: 0.3585 - y2_output_root_mean_squared_error: 0.4882 - val_loss: 1.0771 - val_y1_output_loss: 0.2875 - val_y2_output_loss: 0.7888 - val_y1_output_root_mean_squared_error: 0.5442 - val_y2_output_root_mean_squared_error: 0.8838
# Epoch 498/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3500 - y1_output_loss: 0.1235 - y2_output_loss: 0.2241 - y1_output_root_mean_squared_error: 0.3526 - y2_output_root_mean_squared_error: 0.4750 - val_loss: 0.8664 - val_y1_output_loss: 0.2435 - val_y2_output_loss: 0.6079 - val_y1_output_root_mean_squared_error: 0.4986 - val_y2_output_root_mean_squared_error: 0.7860
# Epoch 499/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3762 - y1_output_loss: 0.1201 - y2_output_loss: 0.2533 - y1_output_root_mean_squared_error: 0.3475 - y2_output_root_mean_squared_error: 0.5054 - val_loss: 0.9287 - val_y1_output_loss: 0.2674 - val_y2_output_loss: 0.6519 - val_y1_output_root_mean_squared_error: 0.5197 - val_y2_output_root_mean_squared_error: 0.8115
# Epoch 500/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3665 - y1_output_loss: 0.1090 - y2_output_loss: 0.2600 - y1_output_root_mean_squared_error: 0.3306 - y2_output_root_mean_squared_error: 0.5071 - val_loss: 1.3019 - val_y1_output_loss: 0.2409 - val_y2_output_loss: 1.0365 - val_y1_output_root_mean_squared_error: 0.4976 - val_y2_output_root_mean_squared_error: 1.0268

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 36us/sample - loss: 1.3019 - y1_output_loss: 0.2502 - y2_output_loss: 1.0436 - y1_output_root_mean_squared_error: 0.4976 - y2_output_root_mean_squared_error: 1.0268
# Loss = 1.3019117178855004, Y1_loss = 0.25016847252845764, Y1_mse = 0.49764350056648254, Y2_loss = 1.043623685836792, Y2_mse = 1.0267729759216309

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
